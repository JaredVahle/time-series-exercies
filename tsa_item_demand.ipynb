# %%
import pandas as pd
import numpy as np 
import acquire
import prepare

# %%
df = acquire.get_item_data()

# %%
df.head()
# Out:
#    sale_id   sale_date  store_id  item_id  sale_amount  store_id  \
# 0        1  2013-01-01         1        1           13         1
# 1        2  2013-01-02         1        1           11         1
# 2        3  2013-01-03         1        1           14         1
# 3        4  2013-01-04         1        1           13         1
# 4        5  2013-01-05         1        1           10         1
#
#             store_address store_zipcode   store_city store_state  item_id  \
# 0  12125 Alamo Ranch Pkwy         78253  San Antonio          TX        1
# 1  12125 Alamo Ranch Pkwy         78253  San Antonio          TX        1
# 2  12125 Alamo Ranch Pkwy         78253  San Antonio          TX        1
# 3  12125 Alamo Ranch Pkwy         78253  San Antonio          TX        1
# 4  12125 Alamo Ranch Pkwy         78253  San Antonio          TX        1
#
#     item_upc14   item_upc12 item_brand                       item_name  \
# ...
